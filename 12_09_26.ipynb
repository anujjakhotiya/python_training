# %% [markdown]
# <a href="https://colab.research.google.com/github/anujjakhotiya/python_training/blob/main/12_09_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sorting:
# why?
# easy access / retireive
# time will be less
# what is sorting?
# arranging the data in a particular order
# Types:
# 1.Bubble sort
# take a value -> compare with neighbour -> if asc, find the max and keep
# if desc find the min and keep it.
# .........................

# %%
n=int(input())
arr =list(map(int,input().split()))
for i in range(n):
  for j in range(i+1, n):
    if (arr[i]>arr[j]):
      arr[i],arr[j]=arr[j],arr[i]
print(arr)
# Out:
# 5
# 3 4 5 2 3
# [2, 3, 3, 4, 5]
